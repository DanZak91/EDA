# %% [markdown]
# --- Commit - фиксация изменений локально. \n
# --- Fork - операция клонирования репозитория в личный аккаунт GitHub для дальнейшего Pull Request. \n
# --- Pull Request - процедура передачи изменеий из форкнутого (личного) репозитория в оригинальный репозитории. \n
